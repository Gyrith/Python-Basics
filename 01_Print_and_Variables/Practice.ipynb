# %% [markdown]
# # Print and Variables
# ## Objectives
# -Understand print()
# -Learn how to create variables
# -Display values using print()

# %%
print('Hello World!')
# Out:
# Hello World!

# %%
print('Welcome to Python')
# Out:
# Welcome to Python

# %%
name = 'Grace'
print(name)
# Out:
# Grace

# %%
age = 24
print(age)
# Out:
# 24

# %%
age = 24
name = 'Grace'
print(f'My name is {name} and i am {age} years old')
# Out:
# My name is Grace and i am 24 years old

# %% [markdown]
# name = 'Grace'
# age = 24
# country = 'Kenya'
# course = 'Data Science'
#
# print('My name is',name)
# print('I am ',age,'years old')
# print('I come from',country)
# print('I am studying',course)

# %%
favourite_food = 'Pilau'
favourite_movie = 'Supernatural'
favourite_language  = 'Python'
print('I love',favourite_food)
print('I love watching',favourite_movie)
print('My favourite programming language is', favourite_language)
# Out:
# I love Pilau
# I love watching Supernatural
# My favourite programming language is Python

# %%
dream_job = 'Data Scientist'
favourite_food = 'Pizza'
favourite_movie = 'Supernatural'
print('Dream' ,dream_job)
print('Food',favourite_food)
print('Movie',favourite_movie)
# Out:
# Dream Data Scientist
# Food Pizza
# Movie Supernatural

# %%
name = 'Mary'
course = 'Data Science'
print(f'My name is {name} and i am studying {course}.')
# Out:
# My name is Mary and i am studying Data Science.

# %%
name = 'Grace' 
age = 24 
country = 'Kenya' 
course = 'Data Science'

print('My name is',name) 
print('I am ',age,'years old') 
print('I come from',country) 
print('I am studying',course)
# Out:
# My name is Grace
# I am  24 years old
# I come from Kenya
# I am studying Data Science

# %%
name = 'Mary'
age = 25
height = 5.9
Is_student = True
print(f'Name',{name})
print('Age',age)
print('Height',height)
print('Is a student',Is_student)
#multiple variables in one print
print(f'{name} is {age} years old and {height} meters tall .')
# Out:
# Name {'Mary'}
# Age 25
# Height 5.9
# Is a student True
# Mary is 25 years old and 5.9 meters tall .

# %%
#Using sep
print('G','Chela',sep='-')
#using end
print('Hello',end =' ')
print('World!')
#Combining sep and end
print('Python','is','awesome',
sep='...',end='\n')
# Out:
# G-Chela
# Hello World!
# Python...is...awesome

# %%
name = 'Joy'
age = 22
#format method
print('Hello, {}. You are {} years old'.format(name,age))
#% formatting
print('Hello, %s. You are %d years old.' %(name,age))
print('I am'  +  str(age) + 'years old.')
# Out:
# Hello, Joy. You are 22 years old
# Hello, Joy. You are 22 years old.
# I am22years old.
